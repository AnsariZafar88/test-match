# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ZAFAR ANSARI\Desktop\test match1.csv") 
df
# Out:
#                                                Player       Span    Mat  \
# 0                                    DG Bradman (AUS)  1928-1948   52.0
# 1                                      AC Voges (AUS)  2015-2016   20.0
# 2                                     RG Pollock (SA)  1963-1970   23.0
# 3                                     GA Headley (WI)  1930-1954   22.0
# 4                                   H Sutcliffe (ENG)  1924-1935   54.0
# ..                                                ...        ...    ...
# 59                                  GC Smith (ICC/SA)  2002-2014  117.0
# 60                                  WH Ponsford (AUS)  1924-1934   29.0
# 61                                    SJ McCabe (AUS)  1930-1938   39.0
# 62                                   DR Jardine (ENG)  1928-1934   22.0
# 63  Adjust:Most recentPast weekPast MonthPast year...        NaN    NaN
#
#      Inns    NO    Runs     HS    Ave     BF     SR   100    50     0      4s  \
# ...

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      1
# Mat       1
# Inns      1
# NO        1
# Runs      1
# HS        1
# Ave       1
# BF        1
# SR        1
# 100       1
# 50        1
# 0         1
# 4s        1
# 6s        1
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.rename(columns = {'Mat':'Matches','NO':'Not_Out','HS':'Highest_score','BF':'Balls_faced','SR':'Strike_Rate'})

# %%
df.head()
# Out:
#               Player       Span  Matches  Inns  Not_Out    Runs  \
# 0   DG Bradman (AUS)  1928-1948     52.0  80.0     10.0  6996.0
# 1     AC Voges (AUS)  2015-2016     20.0  31.0      7.0  1485.0
# 2    RG Pollock (SA)  1963-1970     23.0  41.0      4.0  2256.0
# 3    GA Headley (WI)  1930-1954     22.0  40.0      4.0  2190.0
# 4  H Sutcliffe (ENG)  1924-1935     54.0  84.0      9.0  4555.0
#
#    Highest_score    Ave Balls_faced  Strike_Rate   100    50    0     4s    6s
# 0          334.0  99.94        9800        58.60  29.0  13.0  7.0  626.0   6.0
# 1          269.0  61.87        2667        55.68   5.0   4.0  2.0  186.0   5.0
# 2          274.0  60.97        1707        54.48   7.0  11.0  1.0  246.0  11.0
# 3          270.0  60.83         416        56.00  10.0   5.0  2.0  104.0   1.0
# 4          194.0  60.73        6558        34.59  16.0  23.0  2.0  202.0   6.0

# %%
df.isnull().any()
# Out:
# Player           False
# Span             False
# Matches          False
# Inns             False
# Not_Out          False
# Runs             False
# Highest_score    False
# Ave              False
# Balls_faced      False
# Strike_Rate      False
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# dtype: bool

# %%
df[df['Matches'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Out, Runs, Highest_score, Ave, Balls_faced, Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
df.tail()
# Out:
#                Player       Span  Matches   Inns  Not_Out    Runs  \
# 58   KD Walters (AUS)  1965-1981     74.0  125.0     14.0  5357.0
# 59  GC Smith (ICC/SA)  2002-2014    117.0  205.0     13.0  9265.0
# 60  WH Ponsford (AUS)  1924-1934     29.0   48.0      4.0  2122.0
# 61    SJ McCabe (AUS)  1930-1938     39.0   62.0      5.0  2748.0
# 62   DR Jardine (ENG)  1928-1934     22.0   33.0      6.0  1296.0
#
#     Highest_score    Ave Balls_faced  Strike_Rate   100    50     0      4s  \
# 58          250.0  48.26        8662        49.16  15.0  33.0   4.0   525.0
# 59          277.0  48.25       15525        59.67  27.0  38.0  11.0  1165.0
# 60          266.0  48.22        3118        44.77   7.0   6.0   1.0   119.0
# 61          232.0  48.21        3217        60.02   6.0  13.0   4.0   241.0
# 62          127.0  48.00        2110        25.59   1.0  10.0   2.0    53.0
#
#       6s
# 58  23.0
# 59  24.0
# 60   0.0
# 61   5.0
# 62   0.0

# %%
df.dropna()
# Out:
#                Player       Span  Matches   Inns  Not_Out    Runs  \
# 0    DG Bradman (AUS)  1928-1948     52.0   80.0     10.0  6996.0
# 1      AC Voges (AUS)  2015-2016     20.0   31.0      7.0  1485.0
# 2     RG Pollock (SA)  1963-1970     23.0   41.0      4.0  2256.0
# 3     GA Headley (WI)  1930-1954     22.0   40.0      4.0  2190.0
# 4   H Sutcliffe (ENG)  1924-1935     54.0   84.0      9.0  4555.0
# ..                ...        ...      ...    ...      ...     ...
# 58   KD Walters (AUS)  1965-1981     74.0  125.0     14.0  5357.0
# 59  GC Smith (ICC/SA)  2002-2014    117.0  205.0     13.0  9265.0
# 60  WH Ponsford (AUS)  1924-1934     29.0   48.0      4.0  2122.0
# 61    SJ McCabe (AUS)  1930-1938     39.0   62.0      5.0  2748.0
# 62   DR Jardine (ENG)  1928-1934     22.0   33.0      6.0  1296.0
#
#     Highest_score    Ave Balls_faced  Strike_Rate   100    50     0      4s  \
# 0           334.0  99.94        9800        58.60  29.0  13.0   7.0   626.0
# ...

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 58    False
# 59    False
# 60    False
# 61    False
# 62    False
# Length: 63, dtype: bool

# %%
df = df.drop(['Span'], axis = 1)

# %%
df.head()
# Out:
#               Player  Matches  Inns  Not_Out    Runs  Highest_score    Ave  \
# 0   DG Bradman (AUS)     52.0  80.0     10.0  6996.0          334.0  99.94
# 1     AC Voges (AUS)     20.0  31.0      7.0  1485.0          269.0  61.87
# 2    RG Pollock (SA)     23.0  41.0      4.0  2256.0          274.0  60.97
# 3    GA Headley (WI)     22.0  40.0      4.0  2190.0          270.0  60.83
# 4  H Sutcliffe (ENG)     54.0  84.0      9.0  4555.0          194.0  60.73
#
#   Balls_faced  Strike_Rate   100    50    0     4s    6s
# 0        9800        58.60  29.0  13.0  7.0  626.0   6.0
# 1        2667        55.68   5.0   4.0  2.0  186.0   5.0
# 2        1707        54.48   7.0  11.0  1.0  246.0  11.0
# 3         416        56.00  10.0   5.0  2.0  104.0   1.0
# 4        6558        34.59  16.0  23.0  2.0  202.0   6.0

# %%
df['Player'].str.split(pat = '(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 4     [H Sutcliffe , ENG)]
#               ...
# 58     [KD Walters , AUS)]
# 59    [GC Smith , ICC/SA)]
# 60    [WH Ponsford , AUS)]
# 61      [SJ McCabe , AUS)]
# 62     [DR Jardine , ENG)]
# Name: Player, Length: 63, dtype: object

# %%
df['Country'] = df['Player'].str.split(pat = '(').str[1]

# %%
df['Country'] = df['Country'].str.split(pat = ')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 4        ENG
#        ...
# 58       AUS
# 59    ICC/SA
# 60       AUS
# 61       AUS
# 62       ENG
# Name: Country, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split(pat = '(').str[0]

# %%
df.head(20)
# Out:
#             Player  Matches   Inns  Not_Out     Runs  Highest_score    Ave  \
# 0      DG Bradman      52.0   80.0     10.0   6996.0          334.0  99.94
# 1        AC Voges      20.0   31.0      7.0   1485.0          269.0  61.87
# 2      RG Pollock      23.0   41.0      4.0   2256.0          274.0  60.97
# 3      GA Headley      22.0   40.0      4.0   2190.0          270.0  60.83
# 4     H Sutcliffe      54.0   84.0      9.0   4555.0          194.0  60.73
# 5       E Paynter      20.0   31.0      5.0   1540.0          243.0  59.23
# 6     YBK Jaiswal      13.0   23.0      1.0   1295.0          214.0  58.86
# 7   KF Barrington      82.0  131.0     15.0   6806.0          256.0  58.67
# 8       ED Weekes      48.0   81.0      5.0   4455.0          207.0  58.61
# 9      WR Hammond      85.0  140.0     16.0   7249.0          336.0  58.45
# 10       HC Brook      21.0   35.0      2.0   1908.0          317.0  57.81
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 63 entries, 0 to 62
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Player         63 non-null     object
#  1   Matches        63 non-null     float64
#  2   Inns           63 non-null     float64
#  3   Not_Out        63 non-null     float64
#  4   Runs           63 non-null     float64
#  5   Highest_score  63 non-null     float64
#  6   Ave            63 non-null     float64
#  7   Balls_faced    63 non-null     object
#  8   Strike_Rate    63 non-null     float64
#  9   100            63 non-null     float64
#  10  50             63 non-null     float64
#  11  0              63 non-null     float64
#  12  4s             63 non-null     float64
#  13  6s             63 non-null     float64
#  14  Country        63 non-null     object
# dtypes: float64(12), object(3)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# Player           0
# Matches          0
# Inns             0
# Not_Out          0
# Runs             0
# Highest_score    0
# Ave              0
# Balls_faced      0
# Strike_Rate      0
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# Country          0
# dtype: int64

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x='Runs', y='Player', data=df)
plt.yscale('log')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Country', data=df)
plt.yscale('log')
plt.show()

# %%
top_players = df.nlargest(10, 'Runs')

plt.figure(figsize=(12, 6))
sns.barplot(x='Runs', y='Player', data=top_players, palette='viridis')
plt.title('Top 10 Players by Total Runs')
plt.xlabel('Total Runs')
plt.ylabel('Player')
plt.show()
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_10184\1090824180.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Runs', y='Player', data=top_players, palette='viridis')

# %%
top_players = df.nlargest(10, 'Runs')
plt.figure(figsize=(10, 6))
sns.histplot(df['Runs'], kde=True, bins=20, color='blue')
plt.title('Distribution of Total Runs')
plt.xlabel('Runs')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Strike_Rate', y='Ave', data=df, hue='Runs', size='Runs', sizes=(20, 200), palette='cool')
plt.title('Strike Rate vs Batting Average')
plt.xlabel('Strike Rate')
plt.ylabel('Batting Average')
plt.legend(title='Total Runs', loc='upper left')
plt.show()

# %%
century_players = df.nlargest(20, '100')

plt.figure(figsize=(12, 6))
sns.barplot(x='100', y='Player', data=century_players, palette='plasma')
plt.title('Top 20 Players by Number of Centuries')
plt.xlabel('Number of Centuries')
plt.ylabel('Player')
plt.show()
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_10184\1464492046.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='100', y='Player', data=century_players, palette='plasma')

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='6s', y='Player',  data=top_players, palette='viridis')
plt.title('Top 10 Players by Total 6s')
plt.xlabel('Total 6s')
plt.ylabel('Player')
plt.show()
# Out:
# C:\Users\ZAFAR ANSARI\AppData\Local\Temp\ipykernel_10184\3077245984.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='6s', y='Player',  data=top_players, palette='viridis')
